# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Ou company decided to provide daily free coffee to the employees working at each of the Distirbution Centers located throughout US. In this project we will try to find an optimal location for coffee shops for each individual Distribution Center (further referred to as DC).
#
# We will use our data science analysis to generate closest coffee shops arounf each DC so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of places that sell coffee in the neighborhood
# * distance to coffee places from the DC address
#
# Following data sources will be needed to extract/generate the required information:
# * venues that sell coffee and location in every neighborhood will be obtained using **Foursquare API**
# * coordinate of each will be obtained using **Geocoding**

# %%
#import libraries
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
#!conda install -c conda-forge folium
#!pip install folium==0.5.0
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Get data that was loaded in Watson Studio Assets

# %%
# The code was removed by Watson Studio for sharing.

# %%
df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#     DC          City              Street    Zip
# 0  VHL  Vernon Hills       Milwaukee Ave  60061
# 1  BUR    Burlington            River Rd   8016
# 2  ORL       Orlando  Cypress Lake Drive  32837
# 3  CRL    Carrollton  Trade Center Drive  75261
# 4  FNT       Fontana      Cabernet Drive  92337

# %% [markdown]
# #The Distribution Center are located across US so we need to show all

# %%
address = 'US'

geolocator = Nominatim(user_agent="us_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of US are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of US are 39.7837304, -100.4458825.

# %% [markdown]
# ### Create a data frame from original and add latitude and longitude

# %%
# define the dataframe columns
column_names = ['DC', 'City', 'Street', 'Latitude', 'Longitude'] 

# instantiate the dataframe
dcs = pd.DataFrame(columns=column_names)

# %%
lat=[]
long=[]

for (index_label, row_series)  in df_data_1.iterrows():
    city = row_series.values[1]
    street = row_series.values[2]
    postalcode = row_series.values[3]
          
    address = '{}, {}, {}'.format(street, city, postalcode)
    #print(address)
    geolocator = Nominatim(user_agent="us_explorer")
    location = geolocator.geocode(address)
    lat.append(location.latitude)
    long.append(location.longitude)
   
    

df_data_1['Latitude']=lat
df_data_1['Longitude']=long
df_data_1
# Out:
#     DC          City              Street    Zip   Latitude   Longitude
# 0  VHL  Vernon Hills       Milwaukee Ave  60061  42.253698  -87.946924
# 1  BUR    Burlington            River Rd   8016  39.604460  -74.547454
# 2  ORL       Orlando  Cypress Lake Drive  32837  28.413378  -81.397819
# 3  CRL    Carrollton  Trade Center Drive  75261  32.990442  -96.933770
# 4  FNT       Fontana      Cabernet Drive  92337  34.037067 -117.509472
# 5  SEA        Sumner       32nd Street E  98390  47.228528 -122.254392

# %% [markdown]
# ### Create US map with all DCs

# %%
# create map of New York using latitude and longitude values
map_us= folium.Map(location=[latitude, longitude], zoom_start=5)

# add markers to map
for lat, lng, city, dc in zip(df_data_1['Latitude'], df_data_1['Longitude'], df_data_1['City'], df_data_1['DC']):
    label = '{}, {}'.format(dc, city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=True).add_to(map_us)  
    
map_us
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define limit and radius for all locations

# %%
LIMIT = 10
radius= 5000

category='4bf58dd8d48988d1e0931735'

# %%
# The code was removed by Watson Studio for sharing.

# %%
def getURL(latitude, longitude):
    return  'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# test first DC 

dc1 = df_data_1[df_data_1["DC"]=="SEA"]
url=getURL(df_data_1.loc[0,'Latitude'], df_data_1.loc[0,'Longitude'])
results = requests.get(url).json()
    
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f14e52dd132907d7c508fc5'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'Libertyville',
#   'headerFullLocation': 'Libertyville',
#   'headerLocationGranularity': 'city',
#   'totalResults': 98,
#   'suggestedBounds': {'ne': {'lat': 42.29869794500004,
#     'lng': -87.88624059788772},
#    'sw': {'lat': 42.208697854999954, 'lng': -88.00760660211229}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52fbea09498ee822c9841e2b',
#        'name': "Trader Joe's",
#        'location': {'address': '1600 S Milwaukee Ave',
#         'lat': 42.25516054279883,
#         'lng': -87.94690585327373,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.25516054279883,
#           'lng': -87.94690585327373},
#          {'label': 'entrance', 'lat': 42.255056, 'lng': -87.947026}],
#         'distance': 162,
#         'postalCode': '60048',
#         'cc': 'US',
#         'city': 'Libertyville',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1600 S Milwaukee Ave',
#          'Libertyville, IL 60048',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52fbea09498ee822c9841e2b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b72fdbdf964a52049942de3',
#        'name': 'Starbucks',
#        'location': {'address': '1640 N. Milwaukee Ave.',
#         'lat': 42.25582142,
#         'lng': -87.94826867,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.25582142,
#           'lng': -87.94826867}],
#         'distance': 261,
#         'postalCode': '60061',
#         'cc': 'US',
#         'city': 'Vernon Hills',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1640 N. Milwaukee Ave.',
#          'Vernon Hills, IL 60061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b72fdbdf964a52049942de3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7f3061f964a520ae1d30e3',
#        'name': "Lou Malnati's Pizza",
#        'location': {'address': '1436 S Milwaukee Ave',
#         'lat': 42.26011275688629,
#         'lng': -87.94779314004411,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.26011275688629,
#           'lng': -87.94779314004411},
#          {'label': 'entrance', 'lat': 42.259875, 'lng': -87.947653}],
#         'distance': 717,
#         'postalCode': '60048',
#         'cc': 'US',
#         'city': 'Libertyville',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1436 S Milwaukee Ave',
#          'Libertyville, IL 60048',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '850484',
#         'url': 'https://www.grubhub.com/restaurant/lou-malnatis-pizzeria-1436-s-milwaukee-ave-libertyville/850484?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=850484',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7f3061f964a520ae1d30e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df28f05ae609e69dd969371',
#        'name': "Mariano's Fresh Market",
#        'location': {'address': '1720 N Milwaukee Ave',
#         'lat': 42.25690478217019,
#         'lng': -87.95094791119482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.25690478217019,
#           'lng': -87.95094791119482}],
#         'distance': 487,
#         'postalCode': '60061',
#         'cc': 'US',
#         'city': 'Vernon Hills',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1720 N Milwaukee Ave',
#          'Vernon Hills, IL 60061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df28f05ae609e69dd969371-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c13f11cc8b2fb002cf84304',
#        'name': 'Lazy Dog Restaurant & Bar',
#        'location': {'address': '1115 N Milwaukee Ave',
#         'crossStreet': 'route 60',
#         'lat': 42.24516490381146,
#         'lng': -87.94463215920283,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.24516490381146,
#           'lng': -87.94463215920283}],
#         'distance': 968,
#         'postalCode': '60061',
#         'cc': 'US',
#         'city': 'Vernon Hills',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1115 N Milwaukee Ave (route 60)',
#          'Vernon Hills, IL 60061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c13f11cc8b2fb002cf84304-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5535cb7c498e81dc3df0f79a',
#        'name': 'AMC Hawthorn 12',
#        'location': {'address': '675 Hawthorn Center',
#         'lat': 42.24388491860832,
#         'lng': -87.94893593557552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.24388491860832,
#           'lng': -87.94893593557552}],
#         'distance': 1104,
#         'postalCode': '60061',
#         'cc': 'US',
#         'city': 'Vernon Hills',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['675 Hawthorn Center',
#          'Vernon Hills, IL 60061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5535cb7c498e81dc3df0f79a-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c06b9e78a81c9b6f92c2690',
#        'name': "Burt's Deli",
#        'location': {'address': '114 Greentree Ctr',
#         'crossStreet': 'at Greentree Pkwy',
#         'lat': 42.26391230077099,
#         'lng': -87.95081419927816,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.26391230077099,
#           'lng': -87.95081419927816},
#          {'label': 'entrance', 'lat': 42.264191, 'lng': -87.951017}],
#         'distance': 1181,
#         'postalCode': '60048',
#         'cc': 'US',
#         'city': 'Libertyville',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['114 Greentree Ctr (at Greentree Pkwy)',
#          'Libertyville, IL 60048',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'shortName': 'Deli / Bodega',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c06b9e78a81c9b6f92c2690-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b2fdf78f964a520aff124e3',
#        'name': 'Century Park',
#        'location': {'address': '1001 Lakeview Parkway',
#         'lat': 42.24826929038006,
#         'lng': -87.96115931162751,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.24826929038006,
#           'lng': -87.96115931162751}],
#         'distance': 1319,
#         'postalCode': '60061',
#         'cc': 'US',
#         'city': 'Vernon Hills',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1001 Lakeview Parkway',
#          'Vernon Hills, IL 60061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b2fdf78f964a520aff124e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5362d576498e2cafa254ed31',
#        'name': 'Pho House: Authentic Vietnamese And Asian Cuisine',
#        'location': {'address': '1183 S Milwaukee Ave',
#         'lat': 42.26439022092535,
#         'lng': -87.95089338464862,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.26439022092535,
#           'lng': -87.95089338464862},
#          {'label': 'entrance', 'lat': 42.264003, 'lng': -87.950796}],
#         'distance': 1234,
#         'postalCode': '60048',
#         'cc': 'US',
#         'city': 'Libertyville',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['1183 S Milwaukee Ave',
#          'Libertyville, IL 60048',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5362d576498e2cafa254ed31-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7dabb2f964a5201bef1fe3',
#        'name': "Portillo's",
#        'location': {'address': '221 E Townline Rd',
#         'crossStreet': 'at Lakeview Pkwy',
#         'lat': 42.2398607,
#         'lng': -87.9589182,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.2398607,
#           'lng': -87.9589182}],
#         'distance': 1830,
#         'postalCode': '60061',
#         'cc': 'US',
#         'city': 'Vernon Hills',
#         'state': 'IL',
#         'country': 'United States',
#         'formattedAddress': ['221 E Townline Rd (at Lakeview Pkwy)',
#          'Vernon Hills, IL 60061',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16f941735',
#          'name': 'Hot Dog Joint',
#          'pluralName': 'Hot Dog Joints',
#          'shortName': 'Hot Dogs',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/hotdog_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7dabb2f964a5201bef1fe3-9'}]}]}}

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                         name     categories        lat        lng
# 0               Trader Joe's  Grocery Store  42.255161 -87.946906
# 1                  Starbucks    Coffee Shop  42.255821 -87.948269
# 2        Lou Malnati's Pizza    Pizza Place  42.260113 -87.947793
# 3     Mariano's Fresh Market  Grocery Store  42.256905 -87.950948
# 4  Lazy Dog Restaurant & Bar     Restaurant  42.245165 -87.944632

# %% [markdown]
# ### Create a new dataframe with all DCs and venues

# %%
columns = ['name', 'categories', 'lat', 'lng', 'dc'] 
df_dcs = pd.DataFrame(columns=columns)
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']

for lat, lng, dc in zip(df_data_1['Latitude'].astype('float64'), df_data_1['Longitude'].astype('float64'), df_data_1['DC']):
    url=getURL(lat,lng)
    results = requests.get(url).json()
    #print(results)
    venues = results['response']['groups'][0]['items']
    
    nearby_venues = json_normalize(venues) # flatten JSON

    # filter columns
    
    nearby_venues =nearby_venues.loc[:, filtered_columns]

    # filter the category for each row
    nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

    # clean columns
    nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
     
  
    df_dc= pd.DataFrame(nearby_venues)
    df_dc['DC']=dc
    
    if df_dcs.empty:
        df_dcs = pd.DataFrame(df_dc)
    else:
        df_dcs= df_dcs.append(df_dc)
        
     

df_dcs
# Out:
#                                                 name  \
# 0                                       Trader Joe's
# 1                                          Starbucks
# 2                                Lou Malnati's Pizza
# 3                             Mariano's Fresh Market
# 4                          Lazy Dog Restaurant & Bar
# 5                                    AMC Hawthorn 12
# 6                                        Burt's Deli
# 7                                       Century Park
# 8  Pho House: Authentic Vietnamese And Asian Cuisine
# 9                                         Portillo's
# 0                                  Lower Bank Tavern
# 1                                 jersey cape yachts
# 2                                      Mullica River
# 3                                         S.S. Logan
# 4                                     Green Bank Inn
# 5                        Pine Barrens Liquors & Deli
# 6                            The Lower Bank Bulkhead
# 7                                         The C Spot
# 8                              Turtle Run Campground
# 9                                       Wading River
# 0       Junior Colombian Burger - South Trail Circle
# 1                            Ahmed Indian Restaurant
# 2                                      Twistee Treat
# 3                                Orlando Kart Center
# 4                                       Melao Bakery
# 5                                 Tu Casa Restaurant
# 6                                               Wawa
# 7                                         Wawa #5205
# 8                                             Publix
# 9                                             Kabsah
# 0                                    Daiquiri Shoppe
# 1                                       Super H-Mart
# 2                       La Hacienda Ranch Carrollton
# 3                                        Chick-fil-A
# 4                                     Tous Les Jours
# 5                               Al Markaz Restaurant
# 6                                          LA Burger
# 7                                         Kura Sushi
# 8                                          Charm Juk
# 9                                         Mom's Cafe
# 0                                     Pancho Villa's
# 1                                        Farmer Boys
# 2                                Mr You Chinese Food
# 3                                        Farmer Boys
# 4                                  Viva Villa Market
# 5                                    Southridge Park
# 6                                        Farmer Boys
# 7                                   Jose's Taco Shop
# 8                                    Galleano Winery
# 9                                             SUBWAY
# 0                          The Rock Wood Fired Pizza
# 1                               Half Lion Brewing Co
# 2             The Secret Garden Tea Room & Gift Shop
# 3                                Legendary Doughnuts
# 4                                          Starbucks
# 5                         Farrelli's Wood Fire Pizza
# 6                       CRAFT.19 Espresso + Creperie
# 7                           Toscanos Cafe & Wine Bar
# 8                          The Rock Wood Fired Pizza
# 9                           Dillanos Coffee Roasters
#
#                   categories        lat         lng   DC
# 0              Grocery Store  42.255161  -87.946906  VHL
# 1                Coffee Shop  42.255821  -87.948269  VHL
# 2                Pizza Place  42.260113  -87.947793  VHL
# 3              Grocery Store  42.256905  -87.950948  VHL
# 4                 Restaurant  42.245165  -87.944632  VHL
# 5              Movie Theater  42.243885  -87.948936  VHL
# 6              Deli / Bodega  42.263912  -87.950814  VHL
# 7                       Park  42.248269  -87.961159  VHL
# 8      Vietnamese Restaurant  42.264390  -87.950893  VHL
# 9              Hot Dog Joint  42.239861  -87.958918  VHL
# 0                        Pub  39.616384  -74.540229  BUR
# 1            Harbor / Marina  39.594869  -74.545406  BUR
# 2                      Beach  39.594755  -74.550594  BUR
# 3            Harbor / Marina  39.599060  -74.576704  BUR
# 4                    Brewery  39.615972  -74.579535  BUR
# 5              Deli / Bodega  39.615702  -74.581589  BUR
# 6                      River  39.610475  -74.586342  BUR
# 7                 Campground  39.573501  -74.539485  BUR
# 8                 Campground  39.613154  -74.501589  BUR
# 9                      River  39.617034  -74.498356  BUR
# 0               Burger Joint  28.409365  -81.404989  ORL
# 1          Indian Restaurant  28.401609  -81.403874  ORL
# 2             Ice Cream Shop  28.398679  -81.405038  ORL
# 3              Go Kart Track  28.410904  -81.378922  ORL
# 4  Latin American Restaurant  28.428546  -81.405141  ORL
# 5  Latin American Restaurant  28.428117  -81.404679  ORL
# 6          Convenience Store  28.390377  -81.403686  ORL
# 7          Convenience Store  28.410900  -81.422905  ORL
# 8              Grocery Store  28.388697  -81.402713  ORL
# 9  Middle Eastern Restaurant  28.423961  -81.405600  ORL
# 0                        Bar  32.991567  -96.941585  CRL
# 1                Supermarket  32.984990  -96.911966  CRL
# 2         Mexican Restaurant  32.993238  -96.945573  CRL
# 3       Fast Food Restaurant  32.986170  -96.909283  CRL
# 4                     Bakery  32.984917  -96.911973  CRL
# 5          Indian Restaurant  32.981797  -96.915908  CRL
# 6               Burger Joint  32.984740  -96.908346  CRL
# 7           Sushi Restaurant  32.982086  -96.908073  CRL
# 8          Korean Restaurant  32.985496  -96.912388  CRL
# 9                       Café  32.999434  -96.909397  CRL
# 0         Mexican Restaurant  34.039229 -117.497892  FNT
# 1       Fast Food Restaurant  34.047173 -117.524645  FNT
# 2         Chinese Restaurant  34.017277 -117.505123  FNT
# 3        American Restaurant  34.063325 -117.488309  FNT
# 4         Mexican Restaurant  34.063105 -117.475772  FNT
# 5                       Park  34.039925 -117.485469  FNT
# 6        American Restaurant  34.014727 -117.523921  FNT
# 7         Mexican Restaurant  34.017411 -117.504913  FNT
# 8                     Winery  34.011032 -117.542023  FNT
# 9             Sandwich Place  34.017185 -117.505189  FNT
# 0                Pizza Place  47.231660 -122.239323  SEA
# 1                    Brewery  47.241425 -122.254673  SEA
# 2                   Tea Room  47.210665 -122.232353  SEA
# 3                 Donut Shop  47.243244 -122.210958  SEA
# 4                Coffee Shop  47.204082 -122.228016  SEA
# 5                Pizza Place  47.202866 -122.228564  SEA
# 6                Coffee Shop  47.203531 -122.239735  SEA
# 7         Italian Restaurant  47.194445 -122.253731  SEA
# 8                 Restaurant  47.244725 -122.209515  SEA
# 9                       Café  47.216322 -122.234920  SEA

# %% [markdown]
# ### Joining the main DC data with the venues

# %%
df_final = pd.merge(df_data_1,df_dcs, on="DC", how="inner")
df_final.head(10)
# Out:
#     DC          City         Street    Zip   Latitude  Longitude  \
# 0  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 1  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 2  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 3  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 4  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 5  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 6  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 7  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 8  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 9  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
#
#                                                 name             categories  \
# 0                                       Trader Joe's          Grocery Store
# 1                                          Starbucks            Coffee Shop
# 2                                Lou Malnati's Pizza            Pizza Place
# 3                             Mariano's Fresh Market          Grocery Store
# 4                          Lazy Dog Restaurant & Bar             Restaurant
# 5                                    AMC Hawthorn 12          Movie Theater
# 6                                        Burt's Deli          Deli / Bodega
# 7                                       Century Park                   Park
# 8  Pho House: Authentic Vietnamese And Asian Cuisine  Vietnamese Restaurant
# 9                                         Portillo's          Hot Dog Joint
#
#          lat        lng
# 0  42.255161 -87.946906
# 1  42.255821 -87.948269
# 2  42.260113 -87.947793
# 3  42.256905 -87.950948
# 4  42.245165 -87.944632
# 5  42.243885 -87.948936
# 6  42.263912 -87.950814
# 7  42.248269 -87.961159
# 8  42.264390 -87.950893
# 9  42.239861 -87.958918

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will direct our efforts on detecting venues around each DC
#
# In first step we have collected the required **data: distribution centers with all venues on a specific radius**
#
# Second step in our analysis will be to filter out places that wouldn't see just coffee (eg: Pizza place). For a list of categories to exclude we need to get a distinct list of venues
#
# In third and final step we will focus on most promising areas and within those create **clusters of locations that meet some basic requirements** established in discussion with stakeholders. We will present map of all such locations but also create clusters (using **k-means clustering**) of those locations to identify general zones / neighborhoods / addresses which should be a starting point for final 'street level' exploration and search for optimal venue location by stakeholders.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data.

# %% [markdown]
# ### Find all distinct categories

# %%
cat = df_final['categories'].unique()

print('Distinct categories', cat)
# Out:
# Distinct categories ['Grocery Store' 'Coffee Shop' 'Pizza Place' 'Restaurant' 'Movie Theater'
#  'Deli / Bodega' 'Park' 'Vietnamese Restaurant' 'Hot Dog Joint' 'Pub'
#  'Harbor / Marina' 'Beach' 'Brewery' 'River' 'Campground' 'Burger Joint'
#  'Indian Restaurant' 'Ice Cream Shop' 'Go Kart Track'
#  'Latin American Restaurant' 'Convenience Store'
#  'Middle Eastern Restaurant' 'Bar' 'Supermarket' 'Mexican Restaurant'
#  'Fast Food Restaurant' 'Bakery' 'Sushi Restaurant' 'Korean Restaurant'
#  'Café' 'Chinese Restaurant' 'American Restaurant' 'Winery'
#  'Sandwich Place' 'Tea Room' 'Donut Shop' 'Italian Restaurant']

# %% [markdown]
# ### Remove categories that are not selling coffee

# %%
df_final = df_final.loc[~df_final['categories'].isin(['Harbor / Marina', 'Movie Theater','Go Kart Track','Pizza Place','Grocery Store','Park'])]
cat = df_final['categories'].unique()

print('Distinct categories', cat)
# Out:
# Distinct categories ['Coffee Shop' 'Restaurant' 'Deli / Bodega' 'Vietnamese Restaurant'
#  'Hot Dog Joint' 'Pub' 'Beach' 'Brewery' 'River' 'Campground'
#  'Burger Joint' 'Indian Restaurant' 'Ice Cream Shop'
#  'Latin American Restaurant' 'Convenience Store'
#  'Middle Eastern Restaurant' 'Bar' 'Supermarket' 'Mexican Restaurant'
#  'Fast Food Restaurant' 'Bakery' 'Sushi Restaurant' 'Korean Restaurant'
#  'Café' 'Chinese Restaurant' 'American Restaurant' 'Winery'
#  'Sandwich Place' 'Tea Room' 'Donut Shop' 'Italian Restaurant']

# %% [markdown]
# ### Calculate the distance from each DC to the venues found

# %%
import math 

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

df_final['Distance']  = df_final.apply(lambda x: calc_xy_distance(x['Latitude'],x['Longitude'],x['lat'],x['lng']),axis=1)
df_final.head()
# Out:
#     DC          City         Street    Zip   Latitude  Longitude  \
# 1  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 4  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 6  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 8  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
# 9  VHL  Vernon Hills  Milwaukee Ave  60061  42.253698 -87.946924
#
#                                                 name             categories  \
# 1                                          Starbucks            Coffee Shop
# 4                          Lazy Dog Restaurant & Bar             Restaurant
# 6                                        Burt's Deli          Deli / Bodega
# 8  Pho House: Authentic Vietnamese And Asian Cuisine  Vietnamese Restaurant
# 9                                         Portillo's          Hot Dog Joint
#
#          lat        lng  Distance
# 1  42.255821 -87.948269  0.002514
# 4  42.245165 -87.944632  0.008835
# 6  42.263912 -87.950814  0.010930
# 8  42.264390 -87.950893  0.011405
# 9  42.239861 -87.958918  0.018312

# %% [markdown]
# ### Let's print each DC map with the locations found

# %%
# add markers to map
from IPython.display import display
for lat, lng, city, dc in zip(df_data_1['Latitude'], df_data_1['Longitude'], df_data_1['City'], df_data_1['DC']):
    dcmap= folium.Map(location=[lat, lng], zoom_start=15)
    label = '{}, {}'.format(dc, city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=20,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(dcmap)
    
    venues_dc = df_final[df_final['DC']==dc]
    for lat1, lng1,  name in zip(venues_dc['lat'], venues_dc['lng'], venues_dc['name']):
        dcvenu= folium.Map(location=[lat1, lng1], zoom_start=15)
        label1 = '{}'.format(name)
        label1 = folium.Popup(label1, parse_html=True)
        folium.CircleMarker(
            [lat1, lng1],
            radius=10,
            popup=label1,
            color='red',
            fill=True,
            fill_color='red',
            fill_opacity=0.9,
            parse_html=False).add_to(dcmap)
    display(dcmap)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
### Let's generate clusters, and create a new dataframe that includes the cluster as well as the top 5 venues for each neighborhood.

#T

# %%
from sklearn.cluster import KMeans


# set number of clusters
kclusters = 5

for index in range(len(df_data_1)):
    
    venue_clustering = df_final[df_final['DC']==df_data_1.loc[index,"DC"]]
    venue_grouped=venue_clustering[["Latitude","Longitude","lat","lng"]]

    # run k-means clustering
    kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(venue_grouped)

    # check cluster labels generated for each row in the dataframe
    kmeans.labels_[0:10] 
    
    # add clustering labels
    venue_clustering.insert(0, 'Cluster Labels', kmeans.labels_)
    venue_merged = venue_clustering
       
    # create map
    latitude= df_data_1.loc[index,"Latitude"]
    longitude= df_data_1.loc[index,"Longitude"]
    map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

    # set color scheme for the clusters
    x = np.arange(kclusters)
    ys = [i + x + (i*x)**2 for i in range(kclusters)]
    colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
    rainbow = [colors.rgb2hex(i) for i in colors_array]

    # add markers to the map
    markers_colors = []
    for lat, lon, poi, cluster in zip(venue_merged['Latitude'], venue_merged['Longitude'], venue_merged['name'], venue_merged['Cluster Labels']):
        label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color=rainbow[cluster-1],
            fill=True,
            fill_color=rainbow[cluster-1],
            fill_opacity=0.7).add_to(map_clusters)

    display(map_clusters)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# Our analysis was able to provide the stakeholders with list of venues that can provide coffee.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify places that sell coffee in order to aid stakeholders in narrowing down the search for optimal location. We first got all venues from Foursquare for each DC, then we filtered out places not selling coffee and caluclated the distance to the DC. We mapped all remaining venues around the DCs and allow stakeholders to make decisions.
